# %%
'''
여기서는 seaborn 라이브러리에서 제공하는 데이터셋2)
중에서 타이타닉 테이터셋을 사용한다.
1.행렬 chk
2.컬럼명 chk
3.컬럼별로 유니크값 뽑기 
4.나이 [최소,최대] 
5. 성별로 그룹핑 한다음에 survived 생존한 횟수
6. 남자, 여자 명수
7. 연령대별 사망자 수 0~ 10 ~ 70 ~80 : 남녀 사망자수
'''
# Out:
# '\n여기서는 seaborn 라이브러리에서 제공하는 데이터셋2)\n중에서 타이타닉 테이터셋을 사용한다.\n1.행렬 chk\n2.컬럼명 chk\n3.컬럼별로 유니크값 뽑기 \n4.나이 [최소,최대] \n5. 성별로 그룹핑 한다음에 survived 생존한 횟수\n6. 남자, 여자 명수\n7. 연령대별 사망자 수 0~ 10 ~ 70 ~80 : 남녀 사망자수\n'

# %%
#라이브러리 불러오기
'''
import pandas as pd
import seaborn as sns

titanic = sns.load_dataset('titanic')
print(titanic.columns,"\n",titanic.shape)
df = titanic.loc[:,['age','fare']]
print(df.head(), '\n')
print(type(df),'\n')
'''
# Out:
# '\nimport pandas as pd\nimport seaborn as sns\n\ntitanic = sns.load_dataset(\'titanic\')\nprint(titanic.columns,"\n",titanic.shape)\ndf = titanic.loc[:,[\'age\',\'fare\']]\nprint(df.head(), \'\n\')\nprint(type(df),\'\n\')\n'

# %%
import pandas as pd
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
print(titanic.shape)
# Out:
# (891, 15)

# %%
print(titanic.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
for i in titanic:
    print(titanic[i].unique())
    print()
# Out:
# [0 1]
#
# [3 1 2]
#
# ['male' 'female']
#
# [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.  ]
#
# [1 0 3 4 2 5 8]
#
# [0 1 2 5 3 4 6]
#
# [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55    31.275    7.8542  16.      29.125
#   13.      18.       7.225   26.       8.0292  35.5     31.3875 263.
#    7.8792   7.8958  27.7208 146.5208   7.75    10.5     82.1708  52.
#    7.2292  11.2417   9.475   21.      41.5792  15.5     21.6792  17.8
# ...

# %%
titanic['age'].max()
# Out:
# 80.0

# %%
titanic['age'].min()
# Out:
# 0.42

# %%
a=titanic.groupby(['sex','survived'])['survived'].count()
a[:,0]
# Out:
# sex
# female     81
# male      468
# Name: survived, dtype: int64

# %%
titanic.groupby('sex')['survived'].count()
# Out:
# sex
# female    314
# male      577
# Name: survived, dtype: int64

# %%
#연령대별 사망자수 10~20,20~30,30~40,40~50 남녀 사망자수
titanic.groupby(['age','survived'])['survived'].count()
#ndf = titanic.sort_values(by='age',ascending =True)
a=titanic.groupby(['sex','survived'])['survived'].count()
a[:,0]
# Out:
# sex
# female     81
# male      468
# Name: survived, dtype: int64

# %%
#a = titanic[titanic['survived']==0]
#b = a.groupby('sex')
z =[]
m = ['0~9','10~19','20~29','30~39','40~49','50~59','60~69','70~79','80~89']
for i in range(9):
    z.append(titanic[titanic['age']//10==i]) # // 자연수 값만 돌려줌 
    print(m[i],'female',z[i].groupby('sex')[['survived']==0].count()) 
    print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-62234f094b51> in <module>()
#       5 for i in range(9):
#       6     z.append(titanic[titanic['age']//10==i]) # // 자연수 값만 돌려줌
# ----> 7     print(m[i],'female',z[i].groupby('sex')[['survived']==0].count())
#       8     print()
#
# C:\Anaconda3.5.2\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     265         else:
#     266             if key not in self.obj:
# --> 267                 raise KeyError("Column not found: {key}".format(key=key))
#     268             return self._gotitem(key, ndim=1)
#     269
#
# KeyError: 'Column not found: False'
